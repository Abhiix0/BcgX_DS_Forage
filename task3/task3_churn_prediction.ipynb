# %% [markdown]
# # Customer Churn Prediction using Random Forest
#
# ## Objective
#
# The objective of this notebook is to build a machine learning model capable of predicting customer churn using the engineered dataset provided by PowerCo.
#
# A Random Forest Classifier is chosen because it is an ensemble learning algorithm that combines multiple decision trees, improving prediction accuracy while reducing overfitting. It also provides feature importance scores, allowing us to understand which variables contribute most to customer churn.
#
# This notebook covers:
#
# - Loading and understanding the dataset
# - Preparing the data for modeling
# - Training a Random Forest classifier
# - Evaluating model performance
# - Identifying the most influential features

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

plt.style.use("default")

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/data_for_predictions.csv")

print("Dataset Shape:", df.shape)

df.head()
# Out:
# Dataset Shape: (14606, 64)
#    Unnamed: 0                                id  cons_12m  cons_gas_12m  \
# 0           0  24011ae4ebbe3035111d65fa7c15bc57  0.000000      4.739944
# 1           1  d29c2c54acc38ff3c0614d0a653813dd  3.668479      0.000000
# 2           2  764c75f661154dac3a6c254cd082ea7d  2.736397      0.000000
# 3           3  bba03439a292a1e166f80264c16191cb  3.200029      0.000000
# 4           4  149d57cf92fc41cf94415803a877cb4b  3.646011      0.000000
#
#    cons_last_month  forecast_cons_12m  forecast_discount_energy  \
# 0         0.000000           0.000000                       0.0
# 1         0.000000           2.280920                       0.0
# 2         0.000000           1.689841                       0.0
# 3         0.000000           2.382089                       0.0
# 4         2.721811           2.650065                       0.0
#
#    forecast_meter_rent_12m  forecast_price_energy_off_peak  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 64 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Unnamed: 0                                  14606 non-null  int64
#  1   id                                          14606 non-null  str
#  2   cons_12m                                    14606 non-null  float64
#  3   cons_gas_12m                                14606 non-null  float64
#  4   cons_last_month                             14606 non-null  float64
#  5   forecast_cons_12m                           14606 non-null  float64
#  6   forecast_discount_energy                    14606 non-null  float64
#  7   forecast_meter_rent_12m                     14606 non-null  float64
#  8   forecast_price_energy_off_peak              14606 non-null  float64
#  9   forecast_price_energy_peak                  14606 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                                               count         mean          std  \
# Unnamed: 0                                  14606.0  7302.500000  4216.533351
# cons_12m                                    14606.0     4.223939     0.884515
# cons_gas_12m                                14606.0     0.779244     1.717071
# cons_last_month                             14606.0     2.264646     1.769305
# forecast_cons_12m                           14606.0     2.962177     0.683592
# ...                                             ...          ...          ...
# channel_lmkebamcaaclubfxadlmueccxoimlema    14606.0     0.126181     0.332065
# channel_usilxuppasemubllopkaafesmlibmsdf    14606.0     0.094139     0.292033
# origin_up_kamkkxfxxuwbdslkwifmmcsiusiuosws  14606.0     0.293989     0.455602
# origin_up_ldkssxwpmemidmecebumciepifcamkci  14606.0     0.215528     0.411202
# origin_up_lxidpiddsbxsbosboudacockeimpuepw  14606.0     0.485896     0.499818
#
# ...

# %%
missing = df.isnull().sum()

missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %%
columns_to_drop = []

if "Unnamed: 0" in df.columns:
    columns_to_drop.append("Unnamed: 0")

if "id" in df.columns:
    columns_to_drop.append("id")

df.drop(columns=columns_to_drop, inplace=True)

df.head()
# Out:
#    cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# 0  0.000000      4.739944         0.000000           0.000000
# 1  3.668479      0.000000         0.000000           2.280920
# 2  2.736397      0.000000         0.000000           1.689841
# 3  3.200029      0.000000         0.000000           2.382089
# 4  3.646011      0.000000         2.721811           2.650065
#
#    forecast_discount_energy  forecast_meter_rent_12m  \
# 0                       0.0                 0.444045
# 1                       0.0                 1.237292
# 2                       0.0                 1.599009
# 3                       0.0                 1.318689
# 4                       0.0                 2.122969
#
#    forecast_price_energy_off_peak  forecast_price_energy_peak  \
# 0                        0.114481                    0.098142
# 1                        0.145711                    0.000000
# 2                        0.165794                    0.087899
# ...

# %%
X = df.drop("churn", axis=1)

y = df["churn"]

print(X.shape)
print(y.shape)
# Out:
# (14606, 61)
# (14606,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (11684, 61)
# (2922, 61)

# %%
model = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy :", round(accuracy,4))
# Out:
# Accuracy : 0.9097

# %%
precision = precision_score(y_test, y_pred)

print("Precision :", round(precision,4))
# Out:
# Precision : 0.8571

# %%
recall = recall_score(y_test, y_pred)

print("Recall :", round(recall,4))
# Out:
# Recall : 0.0845

# %%
f1 = f1_score(y_test, y_pred)

print("F1 Score :", round(f1,4))
# Out:
# F1 Score : 0.1538

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2638
#            1       0.86      0.08      0.15       284
#
#     accuracy                           0.91      2922
#    macro avg       0.88      0.54      0.55      2922
# weighted avg       0.91      0.91      0.87      2922

# %%
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm
)

disp.plot(cmap="Blues")

plt.title("Confusion Matrix")

plt.show()

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(15)
# Out:
#                             Feature  Importance
# 0                          cons_12m    0.054676
# 5           forecast_meter_rent_12m    0.052865
# 14                       net_margin    0.052419
# 3                 forecast_cons_12m    0.048673
# 11             margin_gross_pow_ele    0.048387
# 12               margin_net_pow_ele    0.047392
# 15                          pow_max    0.037299
# 2                   cons_last_month    0.036713
# 49                     months_activ    0.031778
# 10                         imp_cons    0.031723
# 51                months_modif_prod    0.029620
# 36      off_peak_peak_var_mean_diff    0.029010
# 22          var_year_price_off_peak    0.027588
# 38  off_peak_mid_peak_var_mean_diff    0.027348
# 16      var_year_price_off_peak_var    0.026976

# %%
plt.figure(figsize=(10,8))

plt.barh(
    importance["Feature"].head(15),
    importance["Importance"].head(15)
)

plt.gca().invert_yaxis()

plt.title("Top 15 Most Important Features")

plt.xlabel("Feature Importance")

plt.show()

# %% [markdown]
# # Model Evaluation
#
# The Random Forest classifier was evaluated using four metrics:
#
# - **Accuracy** measures the overall proportion of correct predictions.
# - **Precision** indicates how many predicted churn cases were actually correct.
# - **Recall** measures how many actual churning customers were successfully identified.
# - **F1-score** provides a balanced measure of precision and recall.
#
# Using multiple evaluation metrics provides a more complete assessment of model performance, particularly because customer churn datasets are often imbalanced.
